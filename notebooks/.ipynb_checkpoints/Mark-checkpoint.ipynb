# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import requests
import json
from pprint import pprint
from config import gkey

csv_path = "../data/Stanford_Data.csv"
solar_df = pd.read_csv(csv_path, delimiter=";" , encoding="ANSI")
solar_df.head()
# Out:
#    Unnamed: 0  tile_count  solar_system_count  total_panel_area         fips  \
# 0           0           0                   0          0.000000  27145011200
# 1           1          25                  21       1133.436461  27145011301
# 2           2           3                   3         64.505776  27145011302
# 3           3           0                   0          0.000000  27145011304
# 4           4           5                   5        164.583303  27145011400
#
#    average_household_income          county  education_bachelor  \
# 0               70352.78987  Stearns County                 569
# 1               61727.08520  Stearns County                 674
# 2               71496.88658  Stearns County                 854
# 3               86840.15275  Stearns County                 640
# 4               89135.31560  Stearns County                 654
#
#    education_college  education_doctoral             ...               \
# 0               1690                  13             ...
# 1               1434                 108             ...
# 2               1459                  31             ...
# 3               1116                  68             ...
# 4               1314                  15             ...
#
#    incentive_count_nonresidential  incentive_residential_state_level  \
# 0                              39                                 11
# 1                              39                                 11
# 2                              39                                 11
# 3                              39                                 11
# 4                              39                                 11
#
#    incentive_nonresidential_state_level  net_metering  feedin_tariff  \
# 0                                    13            34              0
# 1                                    13            34              0
# 2                                    13            34              0
# 3                                    13            34              0
# 4                                    13            34              0
#
#    cooperate_tax  property_tax  sales_tax  rebate  avg_electricity_retail_rate
# 0              0            25         12       0                         9.46
# 1              0            25         12       0                         9.46
# 2              0            25         12       0                         9.46
# 3              0            25         12       0                         9.46
# 4              0            25         12       0                         9.46
#
# [5 rows x 169 columns]

# %%
#sort values for each column to determine which ones carry the most NA values
solar_df.count().sort_values(ascending=True)
# Out:
# voting_2012_dem_percentage                 61983
# voting_2012_gop_percentage                 61983
# cooling_design_temperature                 66735
# elevation                                  66735
# heating_design_temperature                 66735
# earth_temperature_amplitude                66735
# frost_days                                 66735
# lon                                        66735
# air_temperature                            66735
# daily_solar_radiation                      66735
# atmospheric_pressure                       66735
# wind_speed                                 66735
# earth_temperature                          66735
# heating_degree_days                        66735
# cooling_degree_days                        66735
# relative_humidity                          66735
# lat                                        66735
# housing_unit_median_gross_rent             70561
# housing_unit_median_value                  70643
# mortgage_with_rate                         71401
# dropout_16_19_inschool_rate                71476
# median_household_income                    71580
# average_household_income                   71651
# travel_time_average                        71690
# gini_index                                 71690
# poverty_family_below_poverty_level_rate    71714
# average_household_size                     71729
# heating_fuel_electricity_rate              71766
# heating_fuel_fuel_oil_kerosene_rate        71766
# heating_fuel_coal_coke_rate                71766
#                                            ...
# poverty_family_below_poverty_level         72537
# poverty_family_count                       72537
# race_asian                                 72537
# race_black_africa                          72537
# rebate                                     72537
# household_count                            72537
# electricity_consume_total                  72537
# electricity_consume_industrial             72537
# electricity_consume_commercial             72537
# electricity_consume_residential            72537
# electricity_price_overall                  72537
# electricity_price_transportation           72537
# electricity_price_industrial               72537
# electricity_price_commercial               72537
# electricity_price_residential              72537
# housing_unit_occupied_count                72537
# total_panel_area_nonresidential            72537
# solar_system_count_nonresidential          72537
# solar_system_count_residential             72537
# tile_count_nonresidential                  72537
# tile_count_residential                     72537
# unemployed                                 72537
# state                                      72537
# race_white                                 72537
# race_two_more                              72537
# race_other                                 72537
# race_islander                              72537
# race_indian_alaska                         72537
# total_panel_area_residential               72537
# avg_electricity_retail_rate                72537
# Length: 169, dtype: int64

# %%
#delete 2012 dem and gop voting percentage as these have largest contribution to NA data
del solar_df["voting_2012_dem_percentage"]
del solar_df["voting_2012_gop_percentage"]

# %%
#drop all NA values from remaining data set
solar_df = solar_df.dropna(how='any')

# %%
#sort values on remaining dataframe to ensure all columns contain same number of rows with data
solar_df.count().sort_values(ascending=True)
# Out:
# Unnamed: 0                                 63847
# age_more_than_85_rate                      63847
# age_75_84_rate                             63847
# age_35_44_rate                             63847
# age_45_54_rate                             63847
# age_65_74_rate                             63847
# age_55_64_rate                             63847
# age_10_14_rate                             63847
# age_15_17_rate                             63847
# age_5_9_rate                               63847
# household_type_family_rate                 63847
# dropout_16_19_inschool_rate                63847
# occupation_construction_rate               63847
# occupation_public_rate                     63847
# occupation_information_rate                63847
# occupation_finance_rate                    63847
# occupation_education_rate                  63847
# occupation_administrative_rate             63847
# age_25_34_rate                             63847
# occupation_manufacturing_rate              63847
# age_18_24_rate                             63847
# heating_degree_days                        63847
# housing_unit_count                         63847
# housing_unit_occupied_count                63847
# housing_unit_median_value                  63847
# housing_unit_median_gross_rent             63847
# lat                                        63847
# lon                                        63847
# elevation                                  63847
# heating_design_temperature                 63847
#                                            ...
# electricity_price_residential              63847
# electricity_price_commercial               63847
# electricity_price_industrial               63847
# electricity_price_transportation           63847
# electricity_price_overall                  63847
# electricity_consume_residential            63847
# electricity_consume_commercial             63847
# heating_fuel_other_rate                    63847
# water_area                                 63847
# heating_fuel_solar_rate                    63847
# heating_fuel_fuel_oil_kerosene_rate        63847
# education_high_school_graduate_rate        63847
# education_college_rate                     63847
# education_bachelor_rate                    63847
# education_master_rate                      63847
# education_professional_school_rate         63847
# education_doctoral_rate                    63847
# race_white_rate                            63847
# race_black_africa_rate                     63847
# race_indian_alaska_rate                    63847
# race_asian_rate                            63847
# race_islander_rate                         63847
# race_other_rate                            63847
# race_two_more_rate                         63847
# employ_rate                                63847
# poverty_family_below_poverty_level_rate    63847
# heating_fuel_gas_rate                      63847
# heating_fuel_electricity_rate              63847
# heating_fuel_coal_coke_rate                63847
# avg_electricity_retail_rate                63847
# Length: 167, dtype: int64

# %%
#export cleaned data to csv

solar_df.to_csv("../data/Cleaned_Data.csv", index=False, header=True)

# %%
#import cleaned data csv file

csv_path_clean = "../data/Cleaned_Data.csv"
solar_clean_df = pd.read_csv(csv_path_clean, delimiter="," , encoding="ANSI")
solar_clean_df.head()
# Out:
#    Unnamed: 0  tile_count  solar_system_count  total_panel_area         fips  \
# 0           0           0                   0          0.000000  27145011200
# 1           2           3                   3         64.505776  27145011302
# 2           3           0                   0          0.000000  27145011304
# 3           4           5                   5        164.583303  27145011400
# 4           5           0                   0          0.000000  27145011500
#
#    average_household_income          county  education_bachelor  \
# 0               70352.78987  Stearns County                 569
# 1               71496.88658  Stearns County                 854
# 2               86840.15275  Stearns County                 640
# 3               89135.31560  Stearns County                 654
# 4               62225.90361  Stearns County                 522
#
#    education_college  education_doctoral             ...               \
# 0               1690                  13             ...
# 1               1459                  31             ...
# 2               1116                  68             ...
# 3               1314                  15             ...
# 4               1395                  24             ...
#
#    incentive_count_nonresidential  incentive_residential_state_level  \
# 0                              39                                 11
# 1                              39                                 11
# 2                              39                                 11
# 3                              39                                 11
# 4                              39                                 11
#
#    incentive_nonresidential_state_level  net_metering  feedin_tariff  \
# 0                                    13            34              0
# 1                                    13            34              0
# 2                                    13            34              0
# 3                                    13            34              0
# 4                                    13            34              0
#
#    cooperate_tax  property_tax  sales_tax  rebate  avg_electricity_retail_rate
# 0              0            25         12       0                         9.46
# 1              0            25         12       0                         9.46
# 2              0            25         12       0                         9.46
# 3              0            25         12       0                         9.46
# 4              0            25         12       0                         9.46
#
# [5 rows x 167 columns]

# %%
#check that size of new csv is trimmed to ensure it has been cleaned
solar_clean_df.shape
# Out:
# (63847, 167)

# %%
#get unique lat/lon combinations for each county

#group dataframe by county and state

grouped_location = solar_clean_df.groupby(["county", "state"])

#create empty dataframe for sorted county and state data

county_df=pd.DataFrame()

#create new column for total population in each county
county_df["population"]=grouped_location["population"].sum()
county_df["lat"]=grouped_location["lat"].mean()
county_df["lon"]=grouped_location["lon"].mean()

#reset index on county data frame so county names repeat

county_df=county_df.reset_index()
county_df

#determine lat/lon for each county and state from geocode
# Out:
#                       county state  population        lat         lon
# 0           Abbeville County    sc       16713  34.301500  -82.426750
# 1              Acadia Parish    la       44719  30.249556  -92.393000
# 2            Accomack County    va       33115  37.784250  -75.649750
# 3                 Ada County    id      417501  43.607966 -116.273847
# 4               Adair County    ia        4561  41.280000  -94.485500
# 5               Adair County    ky       15219  37.097800  -85.263600
# 6               Adair County    mo       23169  40.200833  -92.591833
# 7               Adair County    ok       17149  35.931250  -94.671500
# 8               Adams County    co      463954  39.872033 -104.928261
# 9               Adams County    ia        2187  40.969000  -94.804000
# 10              Adams County    id        3880  44.934500 -116.416500
# 11              Adams County    il       67081  39.949722  -91.342667
# 12              Adams County    in       34642  40.758143  -84.938000
# 13              Adams County    ms       31979  31.540333  -91.379889
# 14              Adams County    nd        2341  46.114000 -102.497000
# 15              Adams County    ne       28971  40.581625  -98.425375
# 16              Adams County    oh       24682  38.855000  -83.475600
# 17              Adams County    pa       85056  39.850789  -77.160579
# 18              Adams County    wa       19081  46.914800 -118.880400
# 19              Adams County    wi       17788  43.938167  -89.791667
# 20            Addison County    vt       36943  44.060500  -73.153000
# 21              Aiken County    sc      137386  33.525500  -81.777115
# 22             Aitkin County    mn       13974  46.591200  -93.520000
# 23            Alachua County    fl      237600  29.661615  -82.376942
# 24           Alamance County    nc      130684  36.072033  -79.413733
# 25            Alameda County    ca     1560494  37.718347 -122.117911
# 26            Alamosa County    co       16269  37.491750 -105.852750
# 27             Albany County    ny      292679  42.677686  -73.819386
# 28             Albany County    wy       34978  41.337000 -105.601556
# 29          Albemarle County    va       86168  38.040412  -78.522235
# ...                      ...   ...         ...        ...         ...
# 3061          Wyoming County    ny       41446  42.709545  -78.211818
# 3062          Wyoming County    pa       23970  41.525667  -75.940833
# 3063          Wyoming County    wv       22866  37.623500  -81.582833
# 3064            Wythe County    va       24201  36.921600  -81.109200
# 3065           Yadkin County    nc       37971  36.165000  -80.664286
# 3066           Yakima County    wa      209355  46.515359 -120.424744
# 3067        Yalobusha County    ms       12381  34.077333  -89.686000
# 3068          Yamhill County    or       87887  45.239000 -123.157857
# 3069           Yancey County    nc       13744  35.883750  -82.283250
# 3070          Yankton County    sd       22636  42.909800  -97.401000
# 3071            Yates County    ny       25187  42.629800  -77.088800
# 3072          Yavapai County    az      213665  34.618878 -112.275098
# 3073            Yazoo County    ms       27911  32.811500  -90.388000
# 3074             Yell County    ar       15327  35.087750  -93.321500
# 3075  Yellow Medicine County    mn       10092  44.725500  -95.869250
# 3076      Yellowstone County    mt      111801  45.800125 -108.522792
# 3077           Yoakum County    tx        8213  33.121500 -102.829500
# 3078             Yolo County    ca      207320  38.601585 -121.727512
# 3079             York County    me      176109  43.420800  -70.628686
# 3080             York County    ne       13825  40.856750  -97.587500
# 3081             York County    pa      333216  39.943271  -76.757129
# 3082             York County    sc      205229  34.976641  -81.056256
# 3083             York County    va       58267  37.183917  -76.496417
# 3084            Young County    tx       18329  33.157250  -98.618750
# 3085             Yuba County    ca       71747  39.145077 -121.500308
# 3086             Yuma County    az      185600  32.677022 -114.568022
# 3087             Yuma County    co       10185  40.004500 -102.436000
# 3088           Zapata County    tx       14308  26.916667  -99.249000
# 3089           Zavala County    tx       12060  28.835000  -99.786750
# 3090          Ziebach County    sd        2833  44.992000 -101.568000
#
# [3091 rows x 5 columns]
